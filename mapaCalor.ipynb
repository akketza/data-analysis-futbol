# %%
import pandas as pd
from mplsoccer import VerticalPitch, Pitch
from statsbombpy import sb
import matplotlib.pyplot as plt

# %%
#aca se extrae la competiciones
sb.competitions()
#aca se extrae el match

#sb.matches(competition_id=43, season_id=106)
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 62              55         43         Europe           UEFA Euro
# 63              35         75         Europe  UEFA Europa League
# 64              53        106         Europe   UEFA Women's Euro
# 65              72        107  International   Women's World Cup
# 66              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                      False
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 62               male              False                       True
# 63               male              False                      False
# 64             female              False                       True
# 65             female              False                       True
# 66             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2015/2016  2023-08-17T23:51:11.837478                        None
# 1    2018/2019  2023-03-07T12:20:48.118250     2021-06-13T16:17:31.694
# 2    2017/2018  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 3    2016/2017  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 4    2015/2016  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 62        2020  2023-02-24T21:26:47.128979  2023-04-27T22:38:34.970148
# 63   1988/1989  2023-06-18T19:28:39.443883     2021-06-13T16:17:31.694
# 64        2022  2023-07-17T21:19:03.032991  2023-07-17T21:21:56.497106
# 65        2023  2023-08-23T08:11:19.422448  2023-08-22T21:04:15.132891
# 66        2019  2023-07-27T10:33:48.273734     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0                         None  2023-08-17T23:51:11.837478
# 1                         None  2023-03-07T12:20:48.118250
# 2                         None  2021-01-23T21:55:30.425330
# 3                         None            2020-07-29T05:00
# 4                         None            2020-07-29T05:00
# ..                         ...                         ...
# 62  2023-04-27T22:38:34.970148  2023-02-24T21:26:47.128979
# 63                        None  2023-06-18T19:28:39.443883
# 64  2023-07-17T21:21:56.497106  2023-07-17T21:19:03.032991
# 65  2023-08-22T21:04:15.132891  2023-08-22T21:01:33.702562
# 66                        None  2023-07-27T10:33:48.273734
#
# [67 rows x 12 columns]

# %%
#trae los eventos del partido
partido = sb.events(match_id=3869151)
#te da la tabla del partido
partido.head()
# Out:
#   ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                  NaN                            NaN              NaN
# 1                  NaN                            NaN              NaN
# 2                  NaN                            NaN              NaN
# 3                  NaN                            NaN              NaN
# 4                  NaN                            NaN              NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0                NaN                  NaN                 NaN            NaN
# 1                NaN                  NaN                 NaN            NaN
# 2                NaN                  NaN                 NaN            NaN
# 3                NaN                  NaN                 NaN            NaN
# 4                NaN                  NaN                 NaN            NaN
#
#   clearance_left_foot clearance_right_foot counterpress  ... shot_technique  \
# 0                 NaN                  NaN          NaN  ...            NaN
# 1                 NaN                  NaN          NaN  ...            NaN
# 2                 NaN                  NaN          NaN  ...            NaN
# 3                 NaN                  NaN          NaN  ...            NaN
# 4                 NaN                  NaN          NaN  ...            NaN
#
#   shot_type substitution_outcome substitution_replacement  \
# 0       NaN                  NaN                      NaN
# 1       NaN                  NaN                      NaN
# 2       NaN                  NaN                      NaN
# 3       NaN                  NaN                      NaN
# 4       NaN                  NaN                      NaN
#
#                                              tactics       team team_id  \
# 0  {'formation': 433, 'lineup': [{'player': {'id'...  Argentina     779
# 1  {'formation': 442, 'lineup': [{'player': {'id'...  Australia     792
# 2                                                NaN  Argentina     779
# 3                                                NaN  Australia     792
# 4                                                NaN  Australia     792
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
#
# [5 rows x 86 columns]

# %%
#traer los nombres de los jugadores
partido.player.value_counts()
# Out:
# player
# Enzo Fernandez                    311
# Rodrigo Javier De Paul            298
# Nicolás Hernán Otamendi           288
# Lionel Andrés Messi Cuccittini    236
# Cristian Gabriel Romero           230
# Marcos Javier Acuña               201
# Kye Rowles                        197
# Harry Souttar                     194
# Nahuel Molina Lucero              189
# Aaron Mooy                        185
# Alexis Mac Allister               179
# Aziz Eraltay Behich               165
# Mathew Ryan                       148
# Miloš Degenek                     131
# Jackson Irvine                    127
# Alejandro Darío Gómez             122
# Julián Álvarez                    104
# Mathew Leckie                      90
# Mitchell Thomas Duke               89
# Damián Emiliano Martínez           85
# Keanu Baccus                       80
# Riley McGree                       75
# Lautaro Javier Martínez            63
# Ajdin Hrustic                      59
# Lisandro Martínez                  56
# Fran Karačić                       52
# Craig Goodwin                      48
# Nicolás Alejandro Tagliafico       38
# Exequiel Alejandro Palacios        34
# Garang Kuol                        25
# Jamie MacLaren                     16
# Gonzalo Ariel Montiel              16
# Name: count, dtype: int64

# %%
#filtro por jugador
df_jugador = partido[partido['player'] == 'Lionel Andrés Messi Cuccittini']
#llama al data frame 
df_jugador.shape
# Out:
# (236, 86)

# %%
#las columnas te traen todas los endpoints

#df_messi.columns

#locacion me da un array de x y
#se define x, y, location para poder visualizarlo en columnas

df_messi[['x', 'y']] = df_messi.location.apply(pd.Series)
df_messi[['end_x', 'end_y']] = df_messi.pass_end_location.apply(pd.Series)
df_messi[['x', 'y', 'location']]
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_15564\3472806343.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messi[['x', 'y']] = df_messi.location.apply(pd.Series)
# C:\Users\Juan\AppData\Local\Temp\ipykernel_15564\3472806343.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messi[['end_x', 'end_y']] = df_messi.pass_end_location.apply(pd.Series)
# C:\Users\Juan\AppData\Local\Temp\ipykernel_15564\3472806343.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messi[['end_x', 'end_y']] = df_messi.pass_end_location.apply(pd.Series)
#           x     y       location
# 13     27.2  21.5   [27.2, 21.5]
# 74     49.1  44.5   [49.1, 44.5]
# 105    64.1  27.3   [64.1, 27.3]
# 111    56.3  21.3   [56.3, 21.3]
# 115    63.7  28.1   [63.7, 28.1]
# ...     ...   ...            ...
# 4064   95.4  33.6   [95.4, 33.6]
# 4072  104.6  52.2  [104.6, 52.2]
# 4074  102.2  40.0  [102.2, 40.0]
# 4076  106.4  37.0  [106.4, 37.0]
# 4128    NaN   NaN            NaN
#
# [236 rows x 3 columns]

# %%
#se genera el mapa difiniedno ax
fig, ax = plt.subplots(figsize=(16,9))
#como se importo arriba Pitch se trae el tipo statsbomb
pitch = VerticalPitch(pitch_type='statsbomb', line_color='white', pitch_color='black',corner_arcs=True)
#se dibuja la cancha
pitch.draw(ax=ax)
#se llama al kde y se especifica los ax x e y, tambien se le puede dar mas parametros
pitch.kdeplot(
    df_jugador[df_jugador['type'] == 'Pass']['end_x'],
    df_jugador[df_jugador['type'] == 'Pass']['end_y'],
    #df_messi['x'],
    #df_messi['y'],
    ax=ax,
    levels=100,
    fill=True,
    zorder=-1,
    shade_lowest=True,
    thresh=0,
    cut=4,
    cmap='hot'
)
# Out:
# <Axes: >
